# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import to_timestamp, concat_ws, split, hour

spark = SparkSession \
    .builder \
    .appName("Python Spark SQL basic example") \
    .getOrCreate()
# Out:
# Setting default log level to "
# 22/12/08 23:09:48 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# # Top 1000 Tweets da Manhã

# %%
df_morning = spark.read.csv('hdfs:///user/ec2-user/morning-hashtags/')
df_morning.show(1000, truncate=0)
# Out:
# +----------------------------------------------+------+
# |_c0                                           |_c1   |
# +----------------------------------------------+------+
# |#EMABiggestFansJustinBieber                   |100221|
# |#EMABiggestFans1D                             |91176 |
# |#camilasayshi                                 |10517 |
# |#TheVoiceBrasil                               |2799  |
# |#DebateNaRecord                               |2429  |
# |#trndnl                                       |2020  |
# |#QueroDilmaTreze                              |1983  |
# |#Lan                                          |1940  |
# |#debatenarecord                               |1854  |
# |#LinkinParkNoMultishow                        |1854  |
# |#E                                            |1763  |
# |#MasterChefBR                                 |1324  |
# |#TwOff                                        |1285  |
# |#AFazenda                                     |1273  |
# ...

# %% [markdown]
# # Top 1000 Tweets da Tarde

# %%
df_afternoon = spark.read.csv('hdfs:///user/ec2-user/afternoon-hashtags/')
df_afternoon.show(1000, truncate=0)
# Out:
# +--------------------------------------+-----+
# |_c0                                   |_c1  |
# +--------------------------------------+-----+
# |#EMABiggestFans1D                     |80229|
# |#EMABiggestFansJustinBieber           |69887|
# |#StealMyGirl                          |6296 |
# |#QueroNoTVZ                           |5167 |
# |#bigpaynodanceoff                     |4310 |
# |#LuanSantanaNaHoraDoFaro              |2180 |
# |#AustinMahoneChile                    |1536 |
# |#AustinMahone                         |1435 |
# |#demiyourstorydoesntdefineyou         |1301 |
# |#trndnl                               |1181 |
# |#HottieOfTheWeek                      |1042 |
# |#E                                    |1040 |
# |#KCAArgentina                         |970  |
# |#EMABiggestFansArianaGrande           |954  |
# |#EMABiggestFans5SOS                   |913  |
# |#Vote5HEMA                            |910  |
# |#VamosLaU                             |858  |
# ...

# %% [markdown]
# # Top 1000 Tweets da Noite

# %%
df_night = spark.read.csv('hdfs:///user/ec2-user/night-hashtags/')
df_night.show(1000, truncate=0)
# Out:
# +-------------------------------------------+-----+
# |_c0                                        |_c1  |
# +-------------------------------------------+-----+
# |#EMABiggestFans1D                          |44304|
# |#EMABiggestFansJustinBieber                |39606|
# |#DebateNoSBT                               |3313 |
# |#CartersNewVideo                           |3207 |
# |#AssistamODR                               |2436 |
# |#FlyNoMixDiario                            |1514 |
# |#BuyLoveMeHarderOniTunes                   |1474 |
# |#Vote5HEMA                                 |1390 |
# |#LuanSantanaNaHoraDoFaro                   |964  |
# |#Agora                                     |927  |
# |#E                                         |846  |
# |#trndnl                                    |834  |
# |#AUSTINMAHONE                              |738  |
# |#ChatApimentadoDoBiel                      |738  |
# |#QueroNoTVZ                                |737  |
# ...
